# %%
import tweepy
import csv
import pandas as pd
####input your credentials here
consumer_key = 'JaYrP4S5PgTJW0MzIlsGc9DQI'
consumer_secret = '8Ej4dATFYXOuCMg0KOv64Zz3ob2GEg0uycbCu8o21gB0Zl70Cx'
access_token = '1371036616177819648-6SzGKvQMGNpovJ5uc0VDcXpsf06W2o'
access_token_secret = 'TUcqC40Q2mDzBwBAldOJpj7UhroQJrHjlrZNBo4azCa8m'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
#####United Airlines
# Open/Create a file to append data
csvFile = open('10.csv', 'a')
#Use csv Writer
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,q="#WhereIsPM",count=5000,
                           lang="en",
                           since="2021-04-05").items():
    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# 2021-05-23 06:15:35 Is This Not A Massacre? | A New Normal ft. Samdish | Ep. 06 https://t.co/PkcdRItWAK via @YouTube
# #WhereisPM
# 2021-05-22 18:02:24 RT @geetv79: #WhereIsPM ?
# Exporting much-needed vaccines to other countries, while presiding over deaths of Indians.
#
# #ModiFailsIndia
#
# #…
# 2021-05-22 17:43:07 RT @geetv79: #WhereIsPM ?
# Exporting much-needed vaccines to other countries, while presiding over deaths of Indians.
#
# #ModiFailsIndia
#
# #…
# 2021-05-22 16:09:20 RT @john_jssd: #whereIsPM Sad to see the truth of Indians https://t.co/BTaarWHQ1E
# 2021-05-22 15:34:17 RT @hir_patel: Is our Prime minister on leaves?
#
# #WhereIsPM @PMOIndia @narendramodi
# 2021-05-22 04:42:28 Explanation video to @RangarajPandeyR video about DMK MP @DrSenthil_MDRD and about So called India's so called Medi… https://t.co/tlAKG5TN4I
# 2021-05-22 04:28:42 #whereIsPM Sad to see the truth of Indians https://t.co/BTaarWHQ1E
# ...

# %%
# Python Code to Generate a WordCloud 
  
# Importing the Libraries 
from wordcloud import WordCloud, STOPWORDS
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Read 'Youtube05-Shakira.csv' file  
data = pd.read_csv(r"1.csv", encoding ="latin-1")

# %%
#Setting the comment and stop words
comment_words = '' 
stop_words = set(STOPWORDS)

# %%
# Iterating through the .csv data file 
for i in data: 
    i = str(i) 
    seperate = i.split() 
    for j in range(len(seperate)): 
        seperate[j] = seperate[j].lower() 
      
    comment_words += " ".join(seperate)+" "

# %%
# Create the Word Cloud
final_wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='black', 
                stopwords = stop_words, 
                min_font_size = 10).generate(comment_words)

# %%
# Plotting the WordCloud                    
plt.figure(figsize = (10, 10), facecolor = None) 
plt.imshow(final_wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
import numpy as np
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

wine_mask = np.array(Image.open("farmer.png"))

# %%
def transform_format(val):
    if val == 0:
        return 255
    else:
        return val
    
# Transform your mask into a new one that will work with the function:
transformed_wine_mask = np.ndarray((wine_mask.shape[0],wine_mask.shape[1]), np.int32)

for i in range(len(wine_mask)):
    transformed_wine_mask[i] = list(map(transform_format, wine_mask[i]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-a988ab720839> in <module>
#       9
#      10 for i in range(len(wine_mask)):
# ---> 11     transformed_wine_mask[i] = list(map(transform_format, wine_mask[i]))
#
# <ipython-input-34-a988ab720839> in transform_format(val)
#       1 def transform_format(val):
# ----> 2     if val == 0:
#       3         return 255
#       4     else:
#       5         return val
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
